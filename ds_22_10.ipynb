# %%
import pandas as pd


df = pd.read_json("/content/sample_data/anscombe.json")


selected_rows = df.query('X > 5 and Y > 5')

print(selected_rows)
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 8       I  12  10.84
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 19     II  12   9.13
# 20     II   7   7.26
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 30    III  12   8.15
# 31    III   7   6.42
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# 42     IV   8   7.91
# 43     IV   8   6.89

# %%
df['Y']=df['Y'].astype('int')

# %%
df=df.select_dtypes('int')

# %%
col_nam=df.columns.to_list()

# %%
col_nam
# Out:
# ['X', 'Y']

# %%
condition = " > 6  "
conditions=[]
for col in col_nam:
  conditions.append(f'{col}{condition}')
print(conditions)
query_string = ' and '.join(conditions)
print(query_string)
df1=df.query(query_string)
# Out:
# ['X > 6  ', 'Y > 6  ']
# X > 6   and Y > 6

# %%
df1
# Out:
#      X   Y
# 0   10   8
# 2   13   7
# 3    9   8
# 4   11   8
# 5   14   9
# 8   12  10
# 11  10   9
# 12   8   8
# 13  13   8
# 14   9   8
# 15  11   9
# 16  14   8
# 19  12   9
# 20   7   7
# 22  10   7
# 24  13  12
# 25   9   7
# 26  11   7
# 27  14   8
# 30  12   8
# 35   8   7
# 36   8   8
# 37   8   8
# 38   8   7
# 40  19  12
# 42   8   7
